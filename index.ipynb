# %% [markdown]
# # ECON 408: Undergraduate Computational Macroeconomics
#
# ## Getting Started
#
# -   [Environment Setup](pages/setup.qmd) — Installation instructions for Julia, Git, and related tools
# -   [Schedule](pages/schedule.qmd) — Course schedule with lecture topics and problem set due dates
# -   [Notebook repository](https://github.com/jlperla/undergrad_computational_macro_notebooks) — Jupyter notebook versions of slides and problem sets
#
# # Slides
#
# # Other Formats
